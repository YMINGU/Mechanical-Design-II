# %%
# Yuming Gu 4456484 Mechanical Design II homework 2.7
#Problem Statement
#Calculate the minimum dynamic load rating for a rolling-element bearing 
#given a required lifetime, a radial-equivalent load, and a reliability factor

#Basic Variable Setting
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
import math


#(a)For Ball Bearing
L=1500000; #L is the lifetime of the bearing, in rev
F_r=4.4; # F_r is the equivalent load on radial direction, in KN
a=1 # For ball bearing the reliability factor is a=1

#The minimum dynamic load rating for the problem
C1=(L/(a*(10**(6)))**(1/3))*F_r #C is the dynamic load for the ball bearing in KN
print('The minimum dynamic load is {:.3f} KN'.format(C1));

# %%
# Yuming Gu 4456484 Mechanical Design II homework 2.7
#Problem Statement
#Calculate the minimum dynamic load rating for a rolling-element bearing 
#given a required lifetime, a radial-equivalent load, and a reliability factor

#Basic Variable Setting
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
import math


#(a)For Ball Bearing
L=1500000; #L is the lifetime of the bearing, in rev
F_r=4.4; # F_r is the equivalent load on radial direction, in KN
a=1 # For ball bearing the reliability factor is a=1

#The minimum dynamic load rating for the problem
C1=(L/(a*(10**(6)))**(1/3))*F_r #C is the dynamic load for the ball bearing in KN
print('The minimum dynamic load is {:.3f} KN'.format(C1));

# %%
# Yuming Gu 4456484 Mechanical Design II homework 2.7
#Problem Statement
#Calculate the minimum dynamic load rating for a rolling-element bearing 
#given a required lifetime, a radial-equivalent load, and a reliability factor

#Basic Variable Setting
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
import math


#(a)For Ball Bearing
L=float(input("lifetime")); #L is the lifetime of the bearing, in rev
F_r=float(input("equivalent radial load")); # F_r is the equivalent load on radial direction, in KN
a=float(input("reliability factor")) # For Inner ball bearing the reliability factor is a=1, Outer a=1.2

#The minimum dynamic load rating for the problem
C1=((L/(a*(10**(6))))**(1/3))*(F_r) #C is the dynamic load for the ball bearing in KN
print('The minimum dynamic load is {:.3f} KN'.format(C1))
# Out:
# lifetime1200000
# equivalent radial load4.2
# reliability factor1
# The minimum dynamic load is 4.463 KN

# %%
#(b)For Roller Bearing
L=float(input("lifetime")); #L is the lifetime of the bearing, in rev
F_r=float(input("equivalent radial load")); # F_r is the equivalent load on radial direction, in KN
a=float(input("reliability factor")) # For Inner Roller bearing the reliability factor is a=1, Outer a=1.2

#The minimum dynamic load rating for the problem
C2=((L/(a*(10**(6))))**(3/10))*(F_r) #C is the dynamic load for the roller bearing in KN
print('The minimum dynamic load is {:.3f} KN'.format(C2))
# Out:
# lifetime1200000
# equivalent radial load4.2
# reliability factor1
# The minimum dynamic load is 4.436 KN
